# %%
pip install pystokes
# Out:
# Requirement already satisfied: pystokes in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: cython in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from pystokes) (3.2.2)
# Requirement already satisfied: numpy in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from pystokes) (2.3.5)
# Requirement already satisfied: scipy in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from pystokes) (1.16.3)
# Requirement already satisfied: matplotlib in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from pystokes) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from matplotlib->pystokes) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/rajeshsingh/software/anaconda/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->pystokes) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Example 2 : sedimentation of polymers

# %%
import numpy as np
import pystokes
from tqdm import tqdm

from matplotlib import pyplot as plt
import matplotlib.patches as patches

from IPython.display import Video
from matplotlib.animation import FuncAnimation

import os
import io
from PIL import Image

# %%
N=32 ## number of particles
b=1 ## radius of the particle

position0=np.zeros(3*N);
position0[0:N]=-np.arange(0,N)*2*b

fig = plt.figure(); ax = plt.gca();  plt.grid(); plt.axis('equal');
x, y = position0[0:N], position0[N:2*N]

for j in range(N):
    ax.add_patch(patches.Circle((x[j],y[j]),b,color='steelblue',alpha=0.8))

plt.xlim(np.min(x)-b, np.max(x)+b)
plt.ylim(np.min(y)-b, np.max(y)+b)
# Out:
# (-1.0, 1.0)
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
 ## Using pystokes

# particle radius, self-propulsion speed, number and fluid viscosity
b, vs, eta = 1.0, 1, 0.1

rbm   = pystokes.unbounded.Rbm(radius=b, particles=N, viscosity=eta)
force = pystokes.forceFields.Forces(particles=N)

# %%
 # parameters
mu=1/(6*np.pi*eta*b)
dt=0.003
bondLength=2*b
springModulus=100
Nf=1

bendModulus, lje = 50, 0
twistModulus=0

# %%
 def rhs(dX, position):
    F = np.zeros(3*N)
    v = np.zeros(3*N)

    force.multipolymers(Nf, F, position, bondLength, springModulus,  bendModulus, twistModulus)
    for i in range(N):
        F[i+2*N] += Fg
    rbm.mobilityTT(v, position, F)

    for i in range(N):
        dX[i]     = v[i]*dt
        dX[i+N]   = v[i+N]*dt
        dX[i+2*N] = v[i+2*N]*dt
    return

# %%
Lf=N*2*b
paramB=100
Fg = -paramB*bendModulus/(Lf**3)


##----------------------
### integrator
###----------------------
totTime=300
Nt=int(totTime/dt)
X1 = np.zeros((Nt, 3*N));
dX1 = np.zeros(3*N)


position1=position0 # specify initial condition

for i in tqdm(range(Nt)):

    ## saveData
    X1[i,0:3*N]=position1;

    rhs(dX1, position1)

    ## positional update is \dot r = V
    position1 += dX1[0:3*N]
# Out:
# 100%|████████████████████████████████| 100000/100000 [00:02<00:00, 47554.62it/s]

# %%
fig=plt.figure(figsize=(24,5))


ax = fig.add_subplot(1, 4, 1 )
fTp=0
x, y, z = X1[fTp, 0:N],  X1[fTp, N:2*N],  X1[fTp, 2*N:3*N]


for j in range(N):
    ax.add_patch(patches.Circle((x[j],z[j]),b/b,color='maroon',alpha=0.4))
    plt.xlim(np.min(x)-2*b, np.max(x)+2*b)
plt.ylim(np.min(z)-2*b, np.max(z)+2*b)
plt.grid(); plt.axis('equal');
plt.title('$t$=%1.2E s'%((fTp*dt)))
plt.xlabel('x/b')
plt.ylabel('z/b')


ax = fig.add_subplot(1, 4, 2 )

fTp=int(Nt/4)
x, y, z = X1[fTp, 0:N],  X1[fTp, N:2*N],  X1[fTp, 2*N:3*N]
# ax.scatter(x, y, z )

for j in range(N):
    ax.add_patch(patches.Circle((x[j],z[j]),b/b,color='maroon',alpha=0.4))
plt.xlim(np.min(x)-2*b, np.max(x)+2*b)
plt.ylim(np.min(z)-2*b, np.max(z)+2*b)
plt.grid(); plt.axis('equal');
plt.title('$t$=%1.2E s'%((fTp*dt)))
plt.xlabel('x/b')
plt.ylabel('z/b')


ax = fig.add_subplot(1, 4, 3 )

fTp=int(Nt/2)
x, y, z = X1[fTp, 0:N],  X1[fTp, N:2*N],  X1[fTp, 2*N:3*N]
# ax.scatter(x, y, z )
for j in range(N):
    ax.add_patch(patches.Circle((x[j],z[j]),b/b,color='maroon',alpha=.4))
plt.xlim(np.min(x)-2*b, np.max(x)+2*b)
plt.ylim(np.min(z)-2*b, np.max(z)+2*b)
plt.grid(); plt.axis('equal');
plt.title('$t$=%1.2E s'%((fTp*dt)))
plt.xlabel('x/b')
plt.ylabel('z/b')


ax = fig.add_subplot(1, 4, 4 )

fTp=Nt-1
x, y, z = X1[fTp, 0:N],  X1[fTp, N:2*N],  X1[fTp, 2*N:3*N]
# ax.scatter(x, y, z )
for j in range(N):
    ax.add_patch(patches.Circle((x[j],z[j]),b/b,color='maroon',alpha=.4))


plt.xlim(np.min(x)-2*b, np.max(x)+2*b)
plt.ylim(np.min(z)-2*b, np.max(z)+2*b)
plt.grid(); plt.axis('equal');
plt.title('$t$=%1.2E s'%((fTp*dt)))
plt.xlabel('x/b')
plt.ylabel('z/b')
# Out:
# Text(0, 0.5, 'z/b')
